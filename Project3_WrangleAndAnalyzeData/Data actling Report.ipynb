# %% [markdown]
# # Data actling Report

# %% [markdown]
# ### Yes, We All Love Dogs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Stock photo of a Pomeranian dog.
# (Image: © Shutterstock)

# %% [markdown]
# ### And here are some interesting facts from the tweets about dogs

# %% [markdown]
# #### 1. What is the most common breed on twitter?

# %% [markdown]
# Golden retriever has 156 tweets from total 1659, which is around 9.4% of tweets.

# %% [markdown]
# ![%E4%B8%8B%E8%BC%89.png](attachment:%E4%B8%8B%E8%BC%89.png)

# %% [markdown]
# #### Have you ever wondered that among these adorable dogs which breed has the most favorites and retweets?
# From all the tweets we have, we add all the favorites and retweets they got by each breeed and calculate the average favorites and retweets each breed got.

# %% [markdown]
# ![%E4%B8%8B%E8%BC%89%20%281%29.png](attachment:%E4%B8%8B%E8%BC%89%20%281%29.png)![%E4%B8%8B%E8%BC%89%20%282%29.png](attachment:%E4%B8%8B%E8%BC%89%20%282%29.png)![%E4%B8%8B%E8%BC%89%20%283%29.png](attachment:%E4%B8%8B%E8%BC%89%20%283%29.png)![%E4%B8%8B%E8%BC%89%20%284%29.png](attachment:%E4%B8%8B%E8%BC%89%20%284%29.png)

# %% [markdown]
# And it turns out that overall favorite and retweet counts still belongs to golden retriever since they have the most tweets. Bedlington terrier has the average favorite and retweet counts, which may caused by fewer tweets. Therefore, I check how many tweets there are for Bedlington terrier, and find out only 6 tweets for bedlington terrier. Compare with 156 tweets for golden retriever, 6 tweets might be too few to make the call which breed has the highest average favorites and retweets.

# %% [markdown]
# #### Which breed has the highest rating score?

# %% [markdown]
# ![%E4%B8%8B%E8%BC%89%20%285%29.png](attachment:%E4%B8%8B%E8%BC%89%20%285%29.png)![%E4%B8%8B%E8%BC%89%20%286%29.png](attachment:%E4%B8%8B%E8%BC%89%20%286%29.png)

# %% [markdown]
# For all the rating score from the tweets, clumber has the highest and japanese_spaniel has the lowest mean score. I check how many tweet it has, since the score of clumber is much higher than the rest, and find out it only has one tweet. This might explain the huge difference of the mean score.

# %% [markdown]
# #### Does stage of the dog have influence on the rating score?

# %% [markdown]
# ![%E4%B8%8B%E8%BC%89%20%287%29.png](attachment:%E4%B8%8B%E8%BC%89%20%287%29.png)

# %% [markdown]
# The stage of the dog might also have influence on the score they got. And seems that people on twitter tends to give dogs are in the stage of doggo,puppo higher scores.
